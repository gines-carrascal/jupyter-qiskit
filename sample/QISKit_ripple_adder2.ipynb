# %% [markdown]
# # QISKit example: Ripple adder
# Based on Cuccaro, Draper, Kutin & Moulton (2008).
#
# * Gines Carrascal, Complutense University of Madrid
#
# https://github.com/gines-carrascal/jupyter-qiskit

# %%
from qiskit import ClassicalRegister, QuantumRegister
from qiskit import QuantumCircuit
from qiskit import execute
from qiskit import Aer

import qiskit.tools.jupyter

# %%
sumando_1 = input("Primer sumando en binario (4 bits)")
sumando_2 = input("Segundo sumando en binario(4 bits)")
# Out:
# Primer sumando en binario (4 bits)1111
# Segundo sumando en binario(4 bits)0001

# %%
n = 4

a = QuantumRegister(n,"a")
b = QuantumRegister(n+1, "b")
c = QuantumRegister(1, "c")
resultado = ClassicalRegister(n+1, "result")

qc = QuantumCircuit(a,b,c,resultado)

for i in range(n):
    if sumando_1[i] == "1":
        qc.x(a[n - (i+1)])
for i in range(n):
    if sumando_2[i] == "1":
        qc.x(b[n - (i+1)])

for i in range(1, n-1):
    qc.cx(a[i], b[i])

qc.cx(a[1], c[0])

qc.ccx(a[0], b[0], c[0])
qc.cx(a[2], a[1])

qc.ccx(c[0], b[1], a[1])
qc.cx(a[3], a[2])

for i in range(2, n-3):
    qc.ccx(a[i-1], b[i], a[i])
    qc.cx(a[i+2], a[i+1])

qc.ccx(a[n-3], b[n-2], a[n-2])
qc.cx(a[n-1], b[n+1])

qc.ccx(a[n-2], b[n-1], b[n+1])
for i in range(2, n-3):
    qc.x(b[i])

qc.cx(c[0], b[1])
for i in range(2, n-1):
    qc.cx(a[i-1], b[i])

qc.ccx(a[n-3], b[n-2], a[n-2])

for i in range(n-3,2,-1):
    qc.ccx(a[i-1], b[i], a[i])
    qc.cx(a[i+2], a[i+1])
    qc.x(b[i+1])
    
qc.ccx(c[0], b[1], a[1])
qc.cx(a[3], a[2])
qc.x(b[2])

qc.ccx(a[0], b[0], c[0])
qc.cx(a[2], a[1])
qc.x(b[1])

qc.cx(a[1], c[0])

for i in range(n-1):
    qc.cx(a[i], b[i])

qc.measure(b,resultado)

# %%
# %circuit_library_info qc
# Out:
# VBox(children=(Box(children=(Output(layout=Layout(height='auto', max_height='1000px', overflow='hidden scroll'…

# %%
from qiskit import IBMQ, transpile
pro = IBMQ.load_account()
backend = pro.get_backend("ibmq_16_melbourne")

# %%
sc_circ = transpile(qc,backend)
sc_circ.draw(output='mpl')

# %%
# %circuit_library_info sc_circ

# %% [markdown]
# Adding barriers for easiest understanding:

# %%
n = 4

a = QuantumRegister(n,"a")
b = QuantumRegister(n+1, "b")
c = QuantumRegister(1, "c")
resultado = ClassicalRegister(n+1, "result")

qc = QuantumCircuit(a,b,c,resultado)

for i in range(n):
    if sumando_1[i] == "1":
        qc.x(a[n - (i+1)])
for i in range(n):
    if sumando_2[i] == "1":
        qc.x(b[n - (i+1)])

qc.barrier(a,b,c)
for i in range(1, n-1):
    qc.cx(a[i], b[i])
qc.barrier(a,b,c)
qc.cx(a[1], c[0])
qc.barrier(a,b,c)
qc.ccx(a[0], b[0], c[0])
qc.cx(a[2], a[1])
qc.barrier(a,b,c)
qc.ccx(c[0], b[1], a[1])
qc.cx(a[3], a[2])
qc.barrier(a,b,c)
for i in range(2, n-3):
    qc.ccx(a[i-1], b[i], a[i])
    qc.cx(a[i+2], a[i+1])
qc.barrier(a,b,c)
qc.ccx(a[n-3], b[n-2], a[n-2])
qc.cx(a[n-1], b[n+1])
qc.barrier(a,b,c)
qc.ccx(a[n-2], b[n-1], b[n+1])
for i in range(2, n-3):
    qc.x(b[i])
qc.barrier(a,b,c)
qc.cx(c[0], b[1])
for i in range(2, n-1):
    qc.cx(a[i-1], b[i])
qc.barrier(a,b,c)
qc.ccx(a[n-3], b[n-2], a[n-2])
qc.barrier(a,b,c)
for i in range(n-3,2,-1):
    qc.ccx(a[i-1], b[i], a[i])
    qc.cx(a[i+2], a[i+1])
    qc.x(b[i+1])
qc.barrier(a,b,c)
qc.ccx(c[0], b[1], a[1])
qc.cx(a[3], a[2])
qc.x(b[2])
qc.barrier(a,b,c)
qc.ccx(a[0], b[0], c[0])
qc.cx(a[2], a[1])
qc.x(b[1])
qc.barrier(a,b,c)
qc.cx(a[1], c[0])
qc.barrier(a,b,c)
for i in range(n-1):
    qc.cx(a[i], b[i])
qc.barrier(a,b,c)
qc.measure(b,resultado)

# %%
qc.draw(output='mpl')

# %%
my_backend = Aer.get_backend("qasm_simulator")  
job = execute(qc, my_backend, shots=20)
job_stats = job.result().get_counts()
print(job_stats)
# Out:
# {'10000': 20}

# %%
from qiskit.visualization import plot_histogram


# Run in interactive mode
plot_histogram(job_stats)

# %%
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td>Qiskit</td><td>0.18.0</td></tr><tr><td>Terra</td><td>0.13.0</td></tr><tr><td>Aer</td><td>0.5.0</td></tr><tr><td>Ignis</td><td>0.3.0</td></tr><tr><td>Aqua</td><td>0.6.5</td></tr><tr><td>IBM Q Provider</td><td>0.6.0</td></tr><tr><th>System information</th></tr><tr><td>Python</td><td>3.7.6 | packaged by conda-forge | (default, Mar  5 2020, 15:27:18)
# [GCC 7.3.0]</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>1</td></tr><tr><td>Memory (Gb)</td><td>7.776947021484375</td></tr><tr><td colspan='2'>Sat Apr 11 14:12:10 2020 UTC</td></tr></table>
